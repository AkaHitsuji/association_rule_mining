# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from mlxtend.frequent_patterns import apriori
from mlxtend.frequent_patterns import association_rules
from mlxtend.preprocessing import TransactionEncoder

# %%
main_dataset = pd.read_csv("dataset.csv")
main_dataset.drop(main_dataset.columns[0], axis=1, inplace=True)
main_dataset
# Out:
#        encounter_id  patient_nbr             race  gender       age  \
# 0            149190     55629189        Caucasian  Female   [10-20)
# 1             64410     86047875  AfricanAmerican  Female   [20-30)
# 2            500364     82442376        Caucasian    Male   [30-40)
# 3             16680     42519267        Caucasian    Male   [40-50)
# 4             35754     82637451        Caucasian    Male   [50-60)
# 5             55842     84259809        Caucasian    Male   [60-70)
# 6             63768    114882984        Caucasian    Male   [70-80)
# 7             12522     48330783        Caucasian  Female   [80-90)
# 8             15738     63555939        Caucasian  Female  [90-100)
# 9             28236     89869032  AfricanAmerican  Female   [40-50)
# 10            36900     77391171  AfricanAmerican    Male   [60-70)
# 11            40926     85504905        Caucasian  Female   [40-50)
# 12            42570     77586282        Caucasian    Male   [80-90)
# ...

# %%
# only extract relevant data
wanted_cols = ['race','gender','age','A1Cresult','max_glu_serum']
ppl_dataset = main_dataset[wanted_cols]
ppl_dataset[(ppl_dataset['A1Cresult'] != 'None') &
           (ppl_dataset['max_glu_serum'] != 'None')]
# Out:
#                   race  gender      age A1Cresult max_glu_serum
# 151          Caucasian    Male  [80-90)      Norm          >200
# 429    AfricanAmerican  Female  [70-80)        >8          >300
# 550          Caucasian  Female  [50-60)        >8          >300
# 647              Other    Male  [70-80)        >7          >200
# 719          Caucasian  Female  [30-40)        >7          Norm
# 769          Caucasian    Male  [80-90)        >7          >300
# 899           Hispanic  Female  [50-60)        >7          Norm
# 1192         Caucasian  Female  [40-50)        >7          >300
# 1644         Caucasian  Female  [50-60)        >7          >300
# 1861         Caucasian    Male  [50-60)        >8          >200
# 1932         Caucasian    Male  [70-80)        >8          >200
# 1953   AfricanAmerican  Female  [70-80)        >7          >200
# 2174          Hispanic  Female  [70-80)      Norm          >200
# 2339          Hispanic  Female  [50-60)        >8          >300
# ...

# %%
white_data = ppl_dataset[(ppl_dataset['race'] == 'Caucasian') & (ppl_dataset['gender'] == 'Male') & (ppl_dataset['A1Cresult'] != 'None') &
           (ppl_dataset['max_glu_serum'] != 'None')]
white_data
# Out:
#             race gender      age A1Cresult max_glu_serum
# 151    Caucasian   Male  [80-90)      Norm          >200
# 769    Caucasian   Male  [80-90)        >7          >300
# 1861   Caucasian   Male  [50-60)        >8          >200
# 1932   Caucasian   Male  [70-80)        >8          >200
# 3082   Caucasian   Male  [70-80)      Norm          Norm
# 4871   Caucasian   Male  [40-50)        >8          >300
# 5099   Caucasian   Male  [80-90)        >7          >200
# 5808   Caucasian   Male  [70-80)        >8          Norm
# 6125   Caucasian   Male  [70-80)      Norm          >200
# 9554   Caucasian   Male  [70-80)        >8          >300
# 11181  Caucasian   Male  [60-70)        >7          Norm
# 11419  Caucasian   Male  [40-50)        >8          Norm
# 11702  Caucasian   Male  [50-60)        >7          Norm
# 12739  Caucasian   Male  [60-70)        >8          >200
# 12918  Caucasian   Male  [80-90)      Norm          Norm
# ...

# %%
white_data['age'].value_counts(normalize=True)
ages = ['[50-60)','[70-80)','[60-70)','[80-90)','[40-50)','[30-40)','[10-20)']
for age in ages:
    white_data[age] = 12
white_data
# Out:
# /Users/AngYang/anaconda/lib/python3.5/site-packages/ipykernel/__main__.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#             race gender      age A1Cresult max_glu_serum  [50-60)  [70-80)  \
# 151    Caucasian   Male  [80-90)      Norm          >200       12       12
# 769    Caucasian   Male  [80-90)        >7          >300       12       12
# 1861   Caucasian   Male  [50-60)        >8          >200       12       12
# 1932   Caucasian   Male  [70-80)        >8          >200       12       12
# 3082   Caucasian   Male  [70-80)      Norm          Norm       12       12
# 4871   Caucasian   Male  [40-50)        >8          >300       12       12
# 5099   Caucasian   Male  [80-90)        >7          >200       12       12
# ...

# %%
# for index, row in white_data.iterrows():
#     print('checking row',row)
#     for age in ages:
#         if row['age'] == age:
#             white_data.loc[index, row['age']] = 1
# #             white_data[row['age']] = 1
#         else:
#             white_data.loc[index, age] = 0
            
# white_data
